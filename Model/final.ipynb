# %%
import sys
sys.path.append('..')
from results import final_plot

# %%
gan_folder = "GAN/results/gan_v2_1/data.csv"
vae_folder = "VAE/Results/22-03-2024/data.csv"

# %%
import pandas as pd
import matplotlib.pyplot as plt
df_gan = pd.read_csv(gan_folder, index_col=0)
df_vae = pd.read_csv(vae_folder, index_col=0)

# %%
df = pd.concat([df_gan[df_gan['Method']!="GAN rounded"], df_vae[df_vae['Method']=="Sampled VAE gm"]])
final_plot(df)
plt.savefig("final_compare.svg")

# %%
final_plot(df_gan)
plt.savefig("gan.svg")

# %%
final_plot(df_vae)
plt.savefig("vae.svg")
